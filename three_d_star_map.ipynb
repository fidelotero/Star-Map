# %% [markdown]
# #### Fidel C. Otero
#
# #### Student UT EID: fco229
#
# #### Date Created: 10-03-2023
#
# #### Date Last Modified: 10-03-2023

# %%
# import libraries
import math
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ##### 1. Read the Yale Bright Star Catalog and create a Pandas data frame object.

# %%
df = pd.read_csv('bsc5.csv', skipinitialspace=True)

# %%
df.columns
# Out:
# Index(['HR', 'Name', 'DM', 'HD', 'SAO', 'FK5', 'IRflag', 'r_IRflag',
#        'Multiple', 'ADS', 'ADScomp', 'VarID', 'RAh1900', 'RAm1900', 'RAs1900',
#        'DE-1900', 'DEd1900', 'DEm1900', 'DEs1900', 'RAh', 'RAm', 'RAs', 'DE-',
#        'DEd', 'DEm', 'DEs', 'GLON', 'GLAT', 'Vmag', 'n_Vmag', 'u_Vmag', 'B-V',
#        'u_B-V', 'U-B', 'u_U-B', 'R-I', 'n_R-I', 'SpType', 'n_SpType', 'pmRA',
#        'pmDE', 'n_Parallax', 'Parallax', 'RadVel', 'n_RadVel', 'l_RotVel',
#        'RotVel', 'u_RotVel', 'Dmag', 'Sep', 'MultID', 'MultCnt', 'NoteFlag'],
#       dtype='object')

# %%
len(df)
# Out:
# 13605

# %% [markdown]
# ##### 2. Drop all objects that do not have a trigonometric parallax.

# %%
df = df.dropna(subset='Parallax')

# %% [markdown]
# ##### 3. Create a column called Distance that has the distance of the object in parsec. Remember that the inverse of the parallax in arc_seconds is the distance in parsec.

# %%
df['Distance'] = 1 / df['Parallax']

# %%
df['Distance']
# Out:
# 3         71.428571
# 6         21.276596
# 7         20.000000
# 9         14.925373
# 18        31.250000
#             ...
# 13575    100.000000
# 13581    142.857143
# 13591     62.500000
# 13593     76.923077
# 13598     28.571429
# Name: Distance, Length: 3289, dtype: float64

# %% [markdown]
# ##### 4. Use the RA and Dec for the J2000.0 epoch for the next set of computations.

# %%
df['ra'] = (df['RAh'] + (df['RAm'] / 60) + (df['RAs'] / 3600)) * 15

# %%
df['DE-'].replace(to_replace=['+', '-'], value=[1, -1], inplace=True)
df['dec'] = ((df['DEd'] + (df['DEm'] / 60) + (df['DEs'] / 3600)) * df['DE-'])

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
import astropy.coordinates
c = SkyCoord(ra=df['ra']*u.degree, dec=df['dec']*u.degree)

ra = c.ra.wrap_at(180 * u.deg).radian
dec = c.dec.radian

long = c.galactic.l.wrap_at(180 * u.deg).radian
lat = c.galactic.b.radian
r = df['Distance']

# %%
r = r * math.pi / 180
r = np.array(r)

# %%
len(r)
# Out:
# 3289

# %%
len(lat)
# Out:
# 3289

# %%
len(long)
# Out:
# 3289

# %% [markdown]
# ##### 5.  Create three columns x, y, and z that will have the distances to the stars in parsecs in the equatorial frame of reference. Write a routine that will do a coordinate transformation from a spherical coordinate system to a Cartesian system. In this Cartesian system, the x-axis is pointing to the vernal equinox and the x-y plane is the plane of the celestial equator. The z-axis should be pointing to the north celestial pole. You can use the library Astropy for your work.

# %%
df['x'], df['y'], df['z'] = astropy.coordinates.spherical_to_cartesian(r, lat, long)

# %%
df['x']
# Out:
# 3       -0.033287
# 6       -0.168395
# 7        0.109561
# 9       -0.079381
# 18      -0.169672
#            ...
# 13575   -0.817850
# 13581    0.194954
# 13591    0.019022
# 13593   -0.636590
# 13598   -0.167369
# Name: x, Length: 3289, dtype: float64

# %% [markdown]
# ##### 6. Create a column called Color in your data frame. The colors could be named colors like red or blue. Or, the colors could be in hexadecimal format. Here is the color scheme according to spectral types - O (deepest blue), B (medium blue), A (light blue), F (green), G (yellow), K (orange), M (red), and any other star not having a spectral type black.

# %%
colors_dict = {'O': '#7F00FF', 'B': '#0000cd', 'A': '#ADD8E6', 'F': '#008000',
              'G': '#FFFF00', 'K': '#FFA500', 'M': '#ff0000'}

df['colors'] = ''
for ind in df['SpType'].loc[df['SpType'].isna() == False].index:
    for char in df['SpType'][ind]:
        if char.isupper():
            df['colors'][ind] = char
            break
df['colors_hex'] = ''

for ind in df.index:
    if df['colors'][ind] in colors_dict.keys():
        df['colors_hex'][ind] = colors_dict[df['colors'][ind]]
    else:
        df['colors_hex'][ind] = '#000000'
# Out:
# /var/folders/2l/5z_t54nn2mgcnb_rlc4qxcr40000gn/T/ipykernel_54041/3205642460.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['colors'][ind] = char
# /var/folders/2l/5z_t54nn2mgcnb_rlc4qxcr40000gn/T/ipykernel_54041/3205642460.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['colors_hex'][ind] = colors_dict[df['colors'][ind]]
# /var/folders/2l/5z_t54nn2mgcnb_rlc4qxcr40000gn/T/ipykernel_54041/3205642460.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['colors_hex'][ind] = '#000000'

# %%
df.rename(columns={'colors_hex': 'Color'}, inplace=True)
df.drop('colors', axis=1, inplace=True)

# %%
df
# Out:
#            HR       Name           DM        HD       SAO     FK5 IRflag  \
# 3         3.0  33    Psc  BD-06 6357       28.0  128572.0  1002.0      I
# 6         5.0        NaN  BD+57 2865      123.0   21085.0     NaN    NaN
# 7         6.0        NaN  CD-4914337      142.0  214963.0     NaN    NaN
# 9         8.0        NaN  BD+28 4704      166.0   73743.0     NaN    NaN
# 18       15.0  21Alp And  BD+28    4      358.0   73765.0     1.0      I
# ...       ...        ...          ...       ...       ...     ...    ...
# 13575  9094.0        NaN  BD+65 1987   225009.0   10937.0     NaN    NaN
# 13581  9098.0   2    Cet  BD-18 6417   225132.0  147059.0   905.0    NaN
# 13591  9103.0   3    Cet  BD-11 6194   225212.0  147066.0  2001.0      I
# 13593  9104.0        NaN  BD+66 1679   225216.0   10956.0     NaN    NaN
# 13598  9107.0        NaN  BD+33 4828   225239.0   53622.0  2002.0    NaN
#
#       r_IRflag Multiple   ADS  ... MultID MultCnt  NoteFlag    Distance  \
# 3          NaN      NaN   NaN  ...    NaN     3.0         *   71.428571
# 6          NaN      NaN  61.0  ...    NaN     NaN         *   21.276596
# 7          NaN        W   NaN  ...    NaN     NaN         *   20.000000
# 9          NaN      NaN  69.0  ...   AB       4.0         *   14.925373
# 18         NaN      NaN  94.0  ...    NaN     NaN         *   31.250000
# ...        ...      ...   ...  ...    ...     ...       ...         ...
# 13575      NaN      NaN   1.0  ...   AB       3.0         *  100.000000
# 13581      NaN      NaN   NaN  ...    NaN     NaN       NaN  142.857143
# 13591      NaN      NaN   NaN  ...    NaN     NaN       NaN   62.500000
# 13593      NaN      NaN   NaN  ...    NaN     NaN       NaN   76.923077
# 13598      NaN      NaN   NaN  ...    NaN     NaN       NaN   28.571429
#
#              ra        dec         x         y         z    Color
# 3      1.333750  -5.707500 -0.033287  0.507313 -1.138286  #FFA500
# 6      1.566667  58.436667 -0.168395  0.329997 -0.025367  #FFFF00
# 7      1.579167 -49.075000  0.109561 -0.086873 -0.319838  #FFFF00
# 9      1.653333  29.021389 -0.079381  0.203983 -0.141238  #FFA500
# 18     2.097083  29.090556 -0.169672  0.425665 -0.295802  #0000cd
# ...         ...        ...       ...       ...       ...      ...
# 13575  0.650417  66.098889 -0.817850  1.537739  0.112487  #FFFF00
# 13581  0.935000 -17.336111  0.194954  0.603606 -2.411293  #0000cd
# 13591  1.125417 -10.509444  0.019022  0.371852 -1.025317  #FFA500
# 13593  1.175000  67.166667 -0.636590  1.176898  0.110153  #FFA500
# 13598  1.224167  34.659722 -0.167369  0.410565 -0.228236  #FFFF00
#
# [3289 rows x 60 columns]

# %% [markdown]
# ##### 7. Use Plotly to obtain the 3-D distribution of the stars.
# ##### 8. The stars should be color-coded.
# ##### 9. If you hover over a star, you should get the following information - HR Number, Distance in parsec, and Radial Velocity in km/s.

# %%
import plotly.express as px
fig = px.scatter_3d(df, x='x', y='y', z='z',
              color='Color', hover_name='HR', hover_data=['Distance', 'RadVel'], title='3D Map of the Universe')
fig.show()
# Out:
# <div>                            <div id="55843171-fb42-43a5-9670-1e69ff252847" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55843171-fb42-43a5-9670-1e69ff252847")) {                    Plotly.newPlot(                        "55843171-fb42-43a5-9670-1e69ff252847",                        [{"customdata":[[71.42857142857143,-6.0],[14.925373134328357,-8.0],[15.15151515151515,-9.0],[-66.66666666666667,-8.0],[76.92307692307692,19.0],[28.57142857142857,75.0],[43.47826086956522,19.0],[125.0,-52.0],[31.25,-13.0],[166.66666666666666,-12.0],[142.85714285714286,-33.0],[35.714285714285715,-7.0],[10.1010101010101,-34.0],[111.11111111111111,-17.0],[62.5,-4.0],[45.45454545454546,1.0],[100.0,27.0],[27.027027027027028,-24.0],[6.8965517241379315,-13.0],[52.631578947368425,32.0],[40.0,-9.0],[142.85714285714286,34.0],[166.66666666666666,-23.0],[45.45454545454546,2.0],[111.11111111111111,-26.0],[28.57142857142857,5.0],[29.41176470588235,-31.0],[37.03703703703704,7.0],[90.90909090909092,-5.0],[24.390243902439025,12.0],[43.47826086956522,30.0],[142.85714285714286,6.0],[38.46153846153846,-13.0],[76.92307